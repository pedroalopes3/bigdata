# %%
import pandas as pd
import os
import pandas as pd
import os
import pyarrow
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

import cv2

# %% [markdown]
# # **Visual Data**

# %%
#List all Pickle (.pkl) files

pklfiles = [f for f in os.listdir('Project_Features') if os.path.isfile(os.path.join('Project_Features', f)) and f.endswith('_visual.pkl')]
print(pklfiles)

# %%
# Load one
for video in pklfiles:
    print(video)
    data = pd.read_pickle(os.path.join('Project_Features', video))

# Print first lines
print(data.head())

# %%
#Access one frame
data.iloc[0]

# %%
#Lets visualize some features in the images - Poses
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches

frame = 1960

frame_id = data.iloc[frame]['Frame']
print(frame_id)

img = Image.open(frame_id)

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.imshow(img)

for person in data.iloc[frame]['Poses']:

    box = person['bbox']
    # Create a rectangle patch
    rect = patches.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1], linewidth=3, edgecolor='w', facecolor='none')

    # Add patch to the image
    ax.add_patch(rect)

    for kp in person['pose']:

        if kp[2] > 0.5:
            kx, ky = int(kp[0]), int(kp[1])
            # Only draw if the point isn't 0,0 (undetected)
            keypoint = patches.Circle((kx, ky), 10)
            ax.add_patch(keypoint)

# %%
# Facial emotion recognition

fers = data.iloc[frame]['Fer']

print(fers[0].keys())

# %%
print(fers[0]['bbox'])
print(fers[0]['top_emotion'])

print(fers[0]['probabilities'])

print(fers[0]['landmarks'])

# %%
#Visualize emotions and detected faces

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.imshow(img)

fers = data.iloc[frame]['Fer']

for fer in fers:

    x1 = fer['bbox'][0]
    y1 = fer['bbox'][1]
    x2 = fer['bbox'][2]
    y2 = fer['bbox'][3]

    print(fer['top_emotion'])

    # Create a rectangle patch
    rect = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=4, edgecolor='g', facecolor='none')

    # Add patch to the image
    ax.add_patch(rect)

    ax.text(x1, y1, fer['top_emotion'],
            verticalalignment='top',
            color='w')
    
    # We can also visualize the landmarks
    landmarks = fer['landmarks']
    for kp in landmarks:
        
        kx, ky = int(kp[0]), int(kp[1])

        keypoint = patches.Circle((kx, ky), 5)
        ax.add_patch(keypoint)

plt.show()

# %%
### We can also look at the OCR output


pklfiles = [f for f in os.listdir('Project_Features') if os.path.isfile(os.path.join('Project_Features', f)) and f.endswith('_ocr.pkl')]

# Load one
for video in pklfiles:
    print(video)
    data = pd.read_pickle(os.path.join('Project_Features', video))

# Print first lines
print(data.head())

frame = 3000

frame_id = data.iloc[frame]['Frame']
print(frame_id)

img = Image.open(frame_id)

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.imshow(img)

for t in data.iloc[frame]['OCR']:

    box = t['bbox']
    # Create a rectangle patch
    rect = patches.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1], linewidth=10, edgecolor='w', facecolor='none')

    # Add patch to the image
    ax.add_patch(rect)

    print(t['text'])

# %% [markdown]
# # **Audio & Speech**

# %%
#List all Pickle (.pkl) files

pklfiles = [f for f in os.listdir('Project_Features') if os.path.isfile(os.path.join('Project_Features', f)) and f.endswith('_audio.pkl')]
print(pklfiles)

# %%
# Load one
video = 'Ventura_vs_Marques_Mendes_November_25'
data_audio = pd.read_pickle(os.path.join('Project_Features', video + '_audio.pkl'))

# Print first lines
data_audio.head()

# %%
print(data_audio.keys())

# %%
print(data_audio['time stamp'][19:25])
print(data_audio['duration'][19:25])

# %%
print(data_audio.iloc[13])

# %%
#Lets listen
from scipy.io import wavfile
from IPython.display import Audio

samplerate, audio = wavfile.read(os.path.join('Audio', video + '.wav'))

sample = audio[int(data_audio.iloc[13]['time stamp']*samplerate):int(data_audio.iloc[13]['time stamp']+data_audio.iloc[13]['duration'])*samplerate,0]

display(Audio(sample,rate=samplerate))

# %%
#List all Pickle (.pkl) files

pklfiles = [f for f in os.listdir('Project_Features') if os.path.isfile(os.path.join('Project_Features', f)) and f.endswith('_speech.pkl')]
print(pklfiles)

# %%
# Load one
video = 'Ventura_vs_Marques_Mendes_November_25_speech'
data_speech = pd.read_pickle(os.path.join('Project_Features', video + '.pkl'))

# Print first lines
data_speech.head()

# %%
#Verify the transcritp
transcript = data_speech.iloc[13]['transcript']
print(transcript)

# %% [markdown]
# # **Text**

# %%
# Bag-of-Words

from glob import glob

def get_files():
    files = glob('Project_Features/*_speech.pkl')
    return files

corpus = []

trans = get_files()

print(trans)

for file in trans:
    df = pd.read_pickle(file)
    df.to_csv("test.csv", index=True)
    texts = df['transcript']
    for text in texts:
        corpus.append(text)
# Out:
# ['Project_Features/Pinto_vs_Cotrim_Figueiredo_November_24_speech.pkl', 'Project_Features/Seguro_vs_Filipe_December_19_speech.pkl', 'Project_Features/Gouveia_Melo_vs_Ventura_December_15_speech.pkl', 'Project_Features/Ventura_vs_Filipe_December_13_speech.pkl', 'Project_Features/Seguro_vs_Cotrim_Figueiredo_December_17_speech.pkl', 'Project_Features/Seguro_vs_Martins_December_6_speech.pkl', 'Project_Features/Pinto_vs_Marques_Mendes_November_29_speech.pkl', 'Project_Features/Martins_vs_Cotrim_Figueiredo_December_4_speech.pkl', 'Project_Features/Telejornal_TVI_Dec_11_speech.pkl', 'Project_Features/Telejornal_TVI_Dec_18_speech.pkl', 'Project_Features/Filipe_vs_Marques_Mendes_November_18_speech.pkl', 'Project_Features/Seguro_vs_Marques_Mendes_December_3_speech.pkl', 'Project_Features/Telejornal_TVI_Nov_20_speech.pkl', 'Project_Features/Marques_Mendes_vs_Gouveia_Melo_December_21_speech.pkl', 'Project_Features/Telejornal_RTP_Dec_11_speech.pkl', 'Project_Features/Telejornal_TVI_Nov_10_speech.pkl']

# %%
#For a single video
from collections import Counter
def create_bow(text):
  """Creates a Bag-of-Words representation from text.

  Args:
    text: The input text string.

  Returns:
    A dictionary where keys are words and values are their frequencies.
  """
  words = text.lower().split()  # Convert to lowercase and split into words
  word_counts = Counter(words)  # Count word frequencies
  return dict(word_counts)  # Return as a dictionary

bow = create_bow(''.join(corpus))
print(len(bow.keys()))

claramente': 7, 'há': 190, 'nova,': 3, 'menos': 62, 'do': 846, 'mesmo,': 16, 'novos': 7, 'agentes': 6, 'políticos,': 10, 'política': 34, 'portuguesa,': 7, 'querem': 27, 'sua': 97, 'voz,': 1, 'quero': 96, 'voz': 15, 'geração,': 1, 'também,': 29, 'novidade,': 2, 'podem': 30, 'contar': 3, 'comigo': 5, '18': 6, 'an.': 1, 'qual': 34, 'novidade': 2, 'traz?': 1, 'trago': 1, 'maneira': 18, 'diferente': 13, 'política,': 23, 'diferente...': 1, 'outra': 42, 'perda.': 1, 'terrasal,': 1, 'vir.': 1, 'saber': 17, 'causa': 28, 'dessas': 4, 'eleições,': 3, 'ir': 30, 'este': 130, 'falar': 47, 'das': 190, 'automáticas': 2, 'competem': 2, 'presidente': 115, 'república': 88, 'não,': 202, 'exemplo,': 52, 'são': 186, 'adequadas': 1, 'à': 121, 'eleição': 7, 'legislativa.': 1, 'falemos': 2, 'dizem': 11, 'respeito': 9, 'capacidade': 13, 'poderes': 8, 'constituição': 34, 'consagra': 1, 'debates,': 2, 'importantes,': 3, 'outras': 22, 'campanhas,': 1, 'eleições.': 5, 'gostaria': 9, 'falá-semos': 1, 'eleições': 11, 'presenciais': 1, 'papel': 13, 'termino': 1, 'pode': 112, 'ideter': 1, 'num': 26, 'mundo': 13, 'acelerado': 1, 'mudança,': 3, 'que,': 49, '5': 16, 'anos,': 46, 'será': 29, 'se': 676, 'calhar': 4, 'nós': 223, 'conhecemos': 1, 'hoje.': 7, 'importante': 32, 'bem': 58, 'pensam': 1, 'possíveis': 4, 'futuros': 1, 'presidentes': 5, 'república,': 56, 'tenho': 72, 'pensamento': 1, 'concreto.': 2, 'responder': 12, 'sobre': 92, 'supostas': 2, 'existências': 1, 'nunca': 55, 'estivaram': 2, 'cima': 14, 'merda.': 3, 'figlio,': 1, 'ainda': 96, 'vou': 71, 'presidente,': 9, 'esta': 188, 'questão': 54, 'cada': 44, 'fará': 2, 'chegar': 32, 'belaima,': 1, 'colocar': 5, 'seguinte.': 4, 'propósita': 1, 'revelação': 1, 'fez,': 7, 'foi': 251, 'abordado': 1, 'pessoas': 95, 'ligadas': 2, 'marques': 18, 'avançar,': 6, 'diretor': 2,  ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(vocabulary = bow.keys())

# %%
texts = data_speech['transcript']

count_matrix = vectorizer.transform(texts)
BoW = vectorizer.get_feature_names_out()
count_array = count_matrix.toarray()

print(count_array.shape)

for i in range(count_array.shape[0]):
  words = np.where(np.squeeze(count_array[i,:]) != 0)

  print(BoW[words])

# %%
#Load the single file for pool timeline
data_polls = pd.read_pickle(os.path.join('Project_Features', 'polls_timeline.pkl'))

# Print first lines
data_polls.head()

# %%
#Load the single file for parties
data_parties = pd.read_pickle(os.path.join('Project_Features', 'candidate_party.pkl'))

# Print first lines
data_parties.head()
